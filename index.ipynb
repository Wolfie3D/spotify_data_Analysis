# %% [markdown]
# # Spotify Tracks Dataset

# %% [markdown]
# ##### Objectives
#
#     1. Most Popular genre
#     1. Top loudest  genre
#     1. Artist with the most dance able song
#     1. Top instrumentalness songs
#     1. Multiple plots

# %% [markdown]
# ### Load Libraries

# %%
import pandas as pd
import numpy as np 
import matplotlib.pyplot as plt 
import seaborn as sns 

# %matplotlib inline 
pd.set_option('display.max_columns', None)
sns.set_style('darkgrid')

# %% [markdown]
# ## Load the dataset

# %%
data = pd.read_csv(filepath_or_buffer='dataset.csv')

data.head()
# Out:
#    Unnamed: 0                track_id                 artists  \
# 0           0  5SuOikwiRyPMVoIQDJUgSV             Gen Hoshino
# 1           1  4qPNDBW1i3p13qLCt0Ki3A            Ben Woodward
# 2           2  1iJBSr7s7jYXzM8EGcbK5b  Ingrid Michaelson;ZAYN
# 3           3  6lfxq3CG4xtTiEg7opyCyx            Kina Grannis
# 4           4  5vjLSffimiIP26QG5WcN2K        Chord Overstreet
#
#                                           album_name  \
# 0                                             Comedy
# 1                                   Ghost (Acoustic)
# 2                                     To Begin Again
# 3  Crazy Rich Asians (Original Motion Picture Sou...
# 4                                            Hold On
#
#                    track_name  popularity  duration_ms  explicit  \
# 0                      Comedy          73       230666     False
# 1            Ghost - Acoustic          55       149610     False
# 2              To Begin Again          57       210826     False
# ...

# %% [markdown]
# ##### drop the Unnamed: 0 columns

# %%
data.drop('Unnamed: 0', axis = 1, inplace  = True)

data.head()
# Out:
#                  track_id                 artists  \
# 0  5SuOikwiRyPMVoIQDJUgSV             Gen Hoshino
# 1  4qPNDBW1i3p13qLCt0Ki3A            Ben Woodward
# 2  1iJBSr7s7jYXzM8EGcbK5b  Ingrid Michaelson;ZAYN
# 3  6lfxq3CG4xtTiEg7opyCyx            Kina Grannis
# 4  5vjLSffimiIP26QG5WcN2K        Chord Overstreet
#
#                                           album_name  \
# 0                                             Comedy
# 1                                   Ghost (Acoustic)
# 2                                     To Begin Again
# 3  Crazy Rich Asians (Original Motion Picture Sou...
# 4                                            Hold On
#
#                    track_name  popularity  duration_ms  explicit  \
# 0                      Comedy          73       230666     False
# 1            Ghost - Acoustic          55       149610     False
# 2              To Begin Again          57       210826     False
# 3  Can't Help Falling In Love          71       201933     False
# ...

# %%
data.shape
# Out:
# (114000, 20)

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 114000 entries, 0 to 113999
# Data columns (total 20 columns):
#  #   Column            Non-Null Count   Dtype
# ---  ------            --------------   -----
#  0   track_id          114000 non-null  object
#  1   artists           113999 non-null  object
#  2   album_name        113999 non-null  object
#  3   track_name        113999 non-null  object
#  4   popularity        114000 non-null  int64
#  5   duration_ms       114000 non-null  int64
#  6   explicit          114000 non-null  bool
#  7   danceability      114000 non-null  float64
#  8   energy            114000 non-null  float64
#  9   key               114000 non-null  int64
#  10  loudness          114000 non-null  float64
#  11  mode              114000 non-null  int64
#  12  speechiness       114000 non-null  float64
#  13  acousticness      114000 non-null  float64
#  14  instrumentalness  114000 non-null  float64
#  15  liveness          114000 non-null  float64
# ...

# %%
data.describe().T
# Out:
#                      count           mean            std     min  \
# popularity        114000.0      33.238535      22.305078   0.000
# duration_ms       114000.0  228029.153114  107297.712645   0.000
# danceability      114000.0       0.566800       0.173542   0.000
# energy            114000.0       0.641383       0.251529   0.000
# key               114000.0       5.309140       3.559987   0.000
# loudness          114000.0      -8.258960       5.029337 -49.531
# mode              114000.0       0.637553       0.480709   0.000
# speechiness       114000.0       0.084652       0.105732   0.000
# acousticness      114000.0       0.314910       0.332523   0.000
# instrumentalness  114000.0       0.156050       0.309555   0.000
# liveness          114000.0       0.213553       0.190378   0.000
# valence           114000.0       0.474068       0.259261   0.000
# tempo             114000.0     122.147837      29.978197   0.000
# ...

# %% [markdown]
# ## Handling missing values

# %%
data.isna().sum()
# Out:
# track_id            0
# artists             1
# album_name          1
# track_name          1
# popularity          0
# duration_ms         0
# explicit            0
# danceability        0
# energy              0
# key                 0
# loudness            0
# mode                0
# speechiness         0
# acousticness        0
# instrumentalness    0
# liveness            0
# valence             0
# tempo               0
# time_signature      0
# track_genre         0
# dtype: int64

# %% [markdown]
# #### show columns with Nan

# %%
data[data['artists'].isna()]
# Out:
#                      track_id artists album_name track_name  popularity  \
# 65900  1kR4gIb7nGxHPI3D2ifs59     NaN        NaN        NaN           0
#
#        duration_ms  explicit  danceability  energy  key  loudness  mode  \
# 65900            0     False         0.501   0.583    7     -9.46     0
#
#        speechiness  acousticness  instrumentalness  liveness  valence  \
# 65900       0.0605          0.69           0.00396    0.0747    0.734
#
#          tempo  time_signature track_genre
# 65900  138.391               4       k-pop

# %% [markdown]
# The row is being dropped because it lacks essential information in the "artists," "album_name," and "track_name" columns, making it impractical for meaningful analysis or utilization in music-related applications. These missing values compromise data completeness, data quality, and user experience, as having accurate artist and track information is fundamental for correctly categorizing songs, ensuring data integrity, and delivering a satisfactory user experience in music-related contexts. Dropping such rows ensures that the dataset maintains its quality and reliability for subsequent analyses or applications, prioritizing data completeness over quantity.

# %%
data.dropna(inplace=True)

# %%
data.isna().sum()
# Out:
# track_id            0
# artists             0
# album_name          0
# track_name          0
# popularity          0
# duration_ms         0
# explicit            0
# danceability        0
# energy              0
# key                 0
# loudness            0
# mode                0
# speechiness         0
# acousticness        0
# instrumentalness    0
# liveness            0
# valence             0
# tempo               0
# time_signature      0
# track_genre         0
# dtype: int64

# %%
data.shape
# Out:
# (113999, 20)

# %% [markdown]
# ## Data Analysis

# %% [markdown]
# ### Most Popular genre
#
# To identify the most popular genre in your dataset, you can utilize Python and pandas. Start by grouping your data by the "track_genre" column, then compute the average popularity score for each genre group. Following this, sort the genres in descending order based on their average popularity. Finally, you can extract the genre with the highest average popularity, providing you with a clear understanding of the most favored genre in your dataset. This process condenses into a concise procedure that involves grouping, averaging, sorting, and retrieval, allowing you to pinpoint the most popular genre efficiently.

# %%
len(data['track_genre'].value_counts().index)
# Out:
# 114

# %%
data['track_genre'].value_counts().head(10)
# Out:
# party             1000
# idm               1000
# punk              1000
# minimal-techno    1000
# ambient           1000
# study             1000
# metalcore         1000
# romance           1000
# garage            1000
# edm               1000
# Name: track_genre, dtype: int64

# %%
genre_popularity = data.groupby('track_genre')['popularity'].mean()

genre_popularity = genre_popularity.sort_values(ascending=False).reset_index()

genre_popularity = genre_popularity.head(10)

genre_popularity
# Out:
#   track_genre  popularity
# 0    pop-film   59.283000
# 1       k-pop   56.952953
# 2       chill   53.651000
# 3         sad   52.379000
# 4      grunge   49.594000
# 5      indian   49.539000
# 6       anime   48.772000
# 7         emo   48.128000
# 8   sertanejo   47.866000
# 9         pop   47.576000

# %%
sns.barplot(y='track_genre', x='popularity', data= genre_popularity)
# Out:
# <AxesSubplot:xlabel='popularity', ylabel='track_genre'>

# %% [markdown]
# ### Popular Artist
#
# To determine the most popular artist in your dataset, you can employ Python and pandas. Begin by grouping your data based on the "artists" column, then calculate the average popularity score within each artist group. Following this, sort the artists in descending order based on their average popularity. Ultimately, you can extract the artist with the highest average popularity, providing you with a clear understanding of the most favored artist in your dataset. This process combines grouping, averaging, sorting, and retrieval, enabling you to efficiently identify the most popular artist.

# %%
len(data['artists'].value_counts().index)
# Out:
# 31437

# %%
data['artists'].value_counts().head(10)
# Out:
# The Beatles        279
# George Jones       271
# Stevie Wonder      236
# Linkin Park        224
# Ella Fitzgerald    222
# Prateek Kuhad      217
# Feid               202
# Chuck Berry        190
# Håkan Hellström    183
# OneRepublic        181
# Name: artists, dtype: int64

# %%
artist_popularity = data.groupby('artists')['popularity'].mean()

artist_popularity = artist_popularity.sort_values(ascending=False).reset_index()

artist_popularity = artist_popularity.head(10)

artist_popularity
# Out:
#                        artists  popularity
# 0         Sam Smith;Kim Petras       100.0
# 1             Bizarrap;Quevedo        99.0
# 2                Manuel Turizo        98.0
# 3   Bad Bunny;Chencho Corleone        97.0
# 4      Bad Bunny;Bomba Estéreo        94.5
# 5                         Joji        94.0
# 6                      Beyoncé        93.0
# 7                 Harry Styles        92.0
# 8            Rema;Selena Gomez        92.0
# 9  Rauw Alejandro;Lyanno;Brray        91.0

# %%
sns.barplot(y='artists', x='popularity', data= artist_popularity)
plt.xlabel('Popularity')
plt.ylabel('Artists')
plt.title('Popularity of the Artist')
# Out:
# Text(0.5, 1.0, 'Popularity of the Artist')
